# %%
import os
os.getcwd()
os.chdir("C:\\Users\\nathi\\Downloads\\3 Semester\\AMS\\")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.io as pio
from sklearn.ensemble import IsolationForest

names = ['CMX1_S_CP2.csv', 'CMX1_AL_CP2.csv', 'CMX1_AL_CP1.csv', 'CMX1_S_CP1.csv', 'DMC2_S_CP2.csv', 'DMC2_AL_CP2.csv', 'DMC2_AL_CP1.csv', 'DMC2_S_CP1.csv']

dfs = {}

for name in names:
    machine, material, component = name.replace('.csv', '').split('_')
    tempdf = pd.read_csv(f"clean_datasets\{name}") 
    tempdf[['Machine', 'Material', 'Component']] = [machine, material, component]
    print(f"Size of {name}: {tempdf.shape}")

    dfs[name.replace('.csv', '')] = tempdf

df = pd.concat(dfs.values(), ignore_index=True)
display(df.head(5))
# Out:
# <string>:14: SyntaxWarning: invalid escape sequence '\{'
# <>:14: SyntaxWarning: invalid escape sequence '\{'
# <string>:14: SyntaxWarning: invalid escape sequence '\{'
# <>:14: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\3395912845.py:14: SyntaxWarning: invalid escape sequence '\{'
#   tempdf = pd.read_csv(f"clean_datasets\{name}")
# Size of CMX1_S_CP2.csv: (45468, 59)
# Size of CMX1_AL_CP2.csv: (74822, 59)
# Size of CMX1_AL_CP1.csv: (433666, 59)
# Size of CMX1_S_CP1.csv: (244772, 59)
# Size of DMC2_S_CP2.csv: (42016, 59)
# Size of DMC2_AL_CP2.csv: (64337, 59)
# Size of DMC2_AL_CP1.csv: (510050, 59)
# Size of DMC2_S_CP1.csv: (263913, 59)
#      LOAD|1    LOAD|2     LOAD|3  LOAD|6  ENC_POS|1   ENC_POS|2  ENC_POS|3  \
# 0  1.403809  2.349854  24.340820     0.0 -599.99999 -548.200007  -8.400004
# 1  1.501465  2.404785  24.340820     0.0 -600.00000 -548.200007  -8.400024
# 2  1.501465  2.404785  24.340820     0.0 -599.99999 -548.199997  -8.400014
# 3  1.318359  2.343750  24.359131     0.0 -600.00000 -548.199987  -8.400014
# 4  1.318359  2.343750  24.359131     0.0 -599.99999 -548.199997  -8.400024
#
#    ENC_POS|6  CTRL_DIFF2|1  CTRL_DIFF2|2  ...  ENC2_POS|2  ENC2_POS|3  \
# 0  89.995127      -0.00001      0.000007  ... -548.200007   -8.400004
# 1  89.995127       0.00000      0.000007  ... -548.200007   -8.400024
# 2  89.995127      -0.00001     -0.000003  ... -548.199997   -8.400014
# 3  89.995127       0.00000     -0.000013  ... -548.199987   -8.400014
# 4  89.995127      -0.00001     -0.000003  ... -548.199997   -8.400024
#
#    ENC2_POS|6  CURRENT|1  CURRENT|2  CURRENT|3  CURRENT|6  Machine  Material  \
# 0         0.0  -0.256348   0.432373   4.388672        0.0     CMX1         S
# 1         0.0  -0.266602   0.439209   4.378418        0.0     CMX1         S
# 2         0.0  -0.244385   0.423828   4.383545        0.0     CMX1         S
# 3         0.0  -0.254639   0.418701   4.380127        0.0     CMX1         S
# 4         0.0  -0.266602   0.430664   4.381836        0.0     CMX1         S
#
#    Component
# 0        CP2
# 1        CP2
# 2        CP2
# 3        CP2
# 4        CP2
#
# [5 rows x 59 columns]

# %%
material = 'S'
machine = 'DMC2'
component = 'CP2'

df_filtered = df[df['Material'] == material][df['Machine'] == machine][df['Component'] == component].copy()

# create psuedo labels using threshold method
columns_to_predict = ['CURRENT|1', 'CURRENT|2', 'CURRENT|3', 'CURRENT|6']
window_size = df_filtered.shape[0]  # For plotting

for column in columns_to_predict:
    # Drop missing values and reshape
    data = df_filtered[[column]].dropna()

    upp_perc = data.quantile(0.995)[0]
    low_perc = data.quantile(0.005)[0]

    print(upp_perc, low_perc)
    df_filtered[f'{column}_Peak'] = ((df_filtered[column] > upp_perc) | (df_filtered[column] < low_perc))
    
    # Plot limited number of points
    subset = df_filtered.iloc[:window_size]

    plt.figure(figsize=(12, 6))
    plt.plot(subset[column], label='Current')
    plt.plot(subset.index[subset[f'{column}_Peak']], subset[column][subset[f'{column}_Peak']], 'ro', label='Detected Peak')

    plt.title(f"Threshold based method in {column}")
    plt.xlabel("Index")
    plt.ylabel("Current")
    plt.legend()
    plt.tight_layout
    plt.show()

df_filtered.to_csv(f"datasets_pseudo/Threshold/threshold_{machine}_{material}_{component}.csv")
# Out:
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtered = df[df['Material'] == material][df['Machine'] == machine][df['Component'] == component].copy()
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtered = df[df['Material'] == material][df['Machine'] == machine][df['Component'] == component].copy()
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   upp_perc = data.quantile(0.995)[0]
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   low_perc = data.quantile(0.005)[0]
# 1.713867 -1.538086
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   upp_perc = data.quantile(0.995)[0]
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   low_perc = data.quantile(0.005)[0]
# -4.106445 -6.708984
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   upp_perc = data.quantile(0.995)[0]
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   low_perc = data.quantile(0.005)[0]
# 3.3419185750002987 -4.260497725
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   upp_perc = data.quantile(0.995)[0]
# C:\Users\nathi\AppData\Local\Temp\ipykernel_26680\335165833.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   low_perc = data.quantile(0.005)[0]
# 14.96403790000006 -14.141418749999998
